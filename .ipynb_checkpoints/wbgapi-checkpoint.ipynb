# %%
# !pip install wbgapi
# Out:
# Requirement already satisfied: wbgapi in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (1.0.12)
# Requirement already satisfied: PyYAML in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from wbgapi) (6.0)
# Requirement already satisfied: requests in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from wbgapi) (2.28.1)
# Requirement already satisfied: tabulate in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from wbgapi) (0.9.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests->wbgapi) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests->wbgapi) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests->wbgapi) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests->wbgapi) (1.26.13)
# WARNING: You are using pip version 22.0.4; however, version 23.0 is available.
# You should consider upgrading via the '/Users/mac/.pyenv/versions/3.10.3/bin/python3.10 -m pip install --upgrade pip' command.

# %%
import wbgapi as wb
import pandas as pd
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import matplotlib
from datetime import datetime
from dataclasses import dataclass
import pandas as pd
import random
from sklearn.metrics import mean_squared_error

# %%
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
QUERY_ID = ['EN.ATM.METH.EG.KT.CE']

features = ['EN.ATM.METH.EG.ZS','EN.ATM.METH.ZG', 
            'EN.ATM.METH.AG.ZS', 'EN.ATM.METH.AG.KT.CE',
           'NY.GDP.PCAP.CD', 'IS.AIR.DPRT', 'EG.USE.ELEC.KH.PC', 'AG.LND.TOTL.K2', 
            'EN.ATM.METH.AG.KT.CE', 'EN.ATM.METH.AG.ZS','EN.ATM.METH.EG.KT.CE', 'EN.ATM.METH.EG.ZS', 
            'EN.ATM.METH.KT.CE', 'EN.ATM.METH.ZG', 'EG.ELC.NGAS.ZS', 'EG.FEC.RNEW.ZS', 'EG.USE.COMM.FO.ZS',
            'EN.ATM.CO2E.KT', 'EG.USE.PCAP.KG.OE', 'EG.USE.CRNW.ZS'
           ]

BEGIN_YEAR_AVAILABLE = 1990
CURRENT_YEAR_AVAILABLE = 2019

# %% [markdown]
# #### GET OUR DATA FROM WORLD BANK API
#
# We retrieve the data from the API using CountryAlpha2Code and the period time
# - CountryAlpha2Code : Code that identify a country
# - period time: a year or range of year

# %%
def HandlingPeriodFormatInput(year) :
    if year < BEGIN_YEAR_AVAILABLE :
        raise Exception ("The data available starting in 1990")
    if year > CURRENT_YEAR_AVAILABLE : #prediction
        period_time = range(BEGIN_YEAR_AVAILABLE, year)
        return period_time
    else :
        period_time = range(BEGIN_YEAR_AVAILABLE, CURRENT_YEAR_AVAILABLE)
        return period_time

# %%
def HandlingPeriodFormatInput(period_time) :
    
    if type(period_time) == int:      
        period_time = range(BEGIN_YEAR_AVAILABLE, period_time +1)
        return period_time
    
    if period_time[0] < BEGIN_YEAR_AVAILABLE :
        raise Exception ("The data available starting in 1990")
        
    if len(period_time) > 3 :
        raise Exception ("The format given is not correct try this format [initial date, final date, step")
        
    if len(period_time) == 2 :
        period_time.insert(2, 1)
        warnings.warn("the format should be [initial date, final date, step")

    if max(period_time) > CURRENT_YEAR_AVAILABLE + 1 or min(period_time) > CURRENT_YEAR_AVAILABLE:

        new_period_time = range(min(2021, period_time[0]), min(2022, period_time[1]), period_time[2])
    else :
         new_period_time = range(period_time[0], period_time[1], period_time[2])

    return new_period_time

# %%
@dataclass
class Country : 
    name : str
    CountryAlpha2Code : str
    period_time : list
    query_id : list

    def queryMethaneData(self) -> pd.DataFrame : #getDataMethEmissionByCountryAndYears
        period_time_range = HandlingPeriodFormatInput(self.period_time)
        df = wb.data.DataFrame(self.query_id, self.CountryAlpha2Code, time = period_time_range, columns='series')   
        return df.reset_index()
    
    def queryRelatedIndicators(self, predictors) -> pd.DataFrame :
        period_time_range = HandlingPeriodFormatInput(self.period_time)
        df = wb.data.DataFrame(predictors, self.CountryAlpha2Code, time = period_time_range, columns='series')   
        return df.reset_index()
           
    def plot(self):
        try :
            self.queryMethaneData().set_index('time').plot(figsize=(15, 6), title= self.name, colormap='Greens_r')
        except :
            self.queryMethaneData().plot(figsize=(15, 6), title= self.name, colormap='Greens_r')

# %%
country = Country('China', 'CHN', [1990, 2026, 1], QUERY_ID)
data_country = country.queryMethaneData()
country.plot()

# %% [markdown]
# #### DATA PREPROCESSING

# %%
@dataclass
class Preprocessing :
    
    country : Country
    df: pd.DataFrame


    def CleaningAndRename(self):
        self.df['date'] = self.df['time'].str[2:]
        self.df['date'] = pd.to_datetime(self.df['date'])
        self.df = self.df.rename(columns = {'EN.ATM.METH.EG.KT.CE' : 'MethaneEmission'})
        del self.df['time']
        self.df = self.df.set_index('date')


    def HandlingFormatDateIndex(self) :
        BeginYear, LastYearToPredict,_ = self.country.period_time
        start = str(BeginYear) + "-01-01"
        end = str(LastYearToPredict) + "-01-01"
        dates = pd.date_range(start=start,end=end)
        self.df= self.df.reindex(dates, fill_value=0)
        self.df = self.df.resample('Y').sum().reset_index()
        self.df['index'] = self.df['index'].dt.year
        self.df= self.df.rename(columns={'index':'year'})
        self.df = self.df.set_index('year')
        self.df.replace(0.0, pd.np.nan, inplace=True)
        
    def MissingValue(self) :
        return sns.heatmap(self.df.isnull(),yticklabels=True,cbar=True,cmap='viridis')

# %%
df_prepro = Preprocessing(country, data_country)
df_prepro.CleaningAndRename()
df_prepro.HandlingFormatDateIndex()
df_prepro.MissingValue()
# Out:
# <AxesSubplot: ylabel='year'>

# %%
df = df_prepro.df
df
# Out:
#       MethaneEmission
# year
# 1990         251660.0
# 1991         253040.0
# 1992         254530.0
# 1993         262390.0
# 1994         273140.0
# 1995         299460.0
# 1996         295970.0
# 1997         296820.0
# 1998         290410.0
# 1999         286980.0
# 2000         296490.0
# 2001         309020.0
# 2002         320070.0
# 2003         362820.0
# 2004         409430.0
# 2005         453070.0
# 2006         488200.0
# 2007         522070.0
# 2008         530520.0
# 2009         556900.0
# 2010         602590.0
# 2011         650370.0
# 2012         648560.0
# 2013         669010.0
# 2014         677930.0
# 2015         668090.0
# 2016         621840.0
# 2017         633780.0
# 2018         661530.0
# 2019         682870.0
# 2020              NaN
# 2021              NaN
# 2022              NaN
# 2023              NaN
# 2024              NaN
# 2025              NaN
# 2026              NaN

# %% [markdown]
# ### Handling Missing data

# %%
df['MethaneEmission'].hist(bins=30,color='darkred',alpha=0.3)
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='MethaneEmission',data=df,palette='winter')
# Out:
# <AxesSubplot: xlabel='MethaneEmission'>

# %% [markdown]
# #### METHOD I: Rolling Statistical

# %%
def rolling_statistical(df, window_size, kind):
    
    weights = np.linspace(1, window_size, window_size)*0.1
    print(weights)
    df_imputed = df.copy()
    
    for column in df.columns:
        if kind == 'SMA':
            function = df_imputed[column] \
                                .rolling(window_size, min_periods=1) \
                                .mean().interpolate() 
            
            df_imputed[column].fillna(function, inplace=True)
            
        elif kind == 'WMA' :
            function = df_imputed[column].rolling(window_size).apply(
                lambda x: np.sum(weights*x)).interpolate()
            
            df_imputed[column].fillna(function, inplace=True)
            

        elif kind == 'EMA' :
            df_imputed[column] = df_imputed[column].fillna(df_imputed[column].ewm(span=window_size).mean())
            
#     df_imputed[column].plot(figsize=(15, 6), title= 'Rolling_statistical', colormap='jet')
#     plt.show()
            
    return df_imputed

# %%
df_imputed = rolling_statistical(df, 4, 'SMA')
# Out:
# [0.1 0.2 0.3 0.4]

# %%
from sklearn.impute import KNNImputer
def imputwithKNNImputer(df,k):
    imputer = KNNImputer(n_neighbors= k)
    imputed_data = imputer.fit_transform(df)
    df_imputed = pd.DataFrame(imputed_data, 
                           columns = df.columns)
    df_imputed.index = df.index
    for column in df.columns :
        df_imputed[column].plot(figsize=(15, 6), title= 'KNNImputer', colormap='jet')
        plt.show()
      
    return df_imputed

# %%
df_imputed = imputwithKNNImputer(df, 3)

# %%
def Imputewithlinear_interpolation(df, order, kind='linear'):
    for column in df.columns :
        df[column ] = df[column].interpolate(method=kind, order=order)
        df[column].plot(figsize=(15, 6), title= 'linear_interpolation', colormap='jet')
        plt.show()
    return df

# %%
df_imputed = Imputewithlinear_interpolation(df, 1)

# %%
def compute_uncertainty(df, model, nbr_sim, kind_rolling= 'SMA', kind_interpo= 'linear', order = 1, windows_size = 4, k=3):
    df = df.dropna()
    for column in df.columns :
        all_estimations_error = []
        for _ in range(1, nbr_sim + 1) :
            df_random_null_value = replace_random_values(df, 0.5)
            if model == 'rolling_statistical' :
                df_predict = rolling_statistical(df_random_null_value, windows_size, kind)
            elif model == 'KNNImputer' :
                df_predict = imputwithKNNImputer(df_random_null_value , k)
                
        
            elif model == 'Linear_interpolation':
                    df_predict = Imputewithlinear_interpolation(df_random_null_value, order, kind= kind_interpo)
                    
                
            mse = np.sqrt(mean_squared_error(df[column], df_predict[column]))
            all_estimations_error.append(mse)

        # compute the mean, standard deviation and confidence interval of the results
        mean = np.mean(all_estimations_error)
        std = np.std(all_estimations_error)
        confidence_interval = (mean - 1.96*std, mean + 1.96*std)
        print('Mean: ', mean)
        print('Standard deviation: ', std)
        print('Confidence interval: ', confidence_interval)
        
        return std

# %%
def replace_random_values(df, fraction):
    for column in df.columns:
        df_train = df.copy()
        print(np.random.rand(len(df_train)))
        mask = np.random.rand(len(df_train)) < fraction
        if mask[0] == True:
            mask[0] = False
        df_train[column][mask] = np.nan
    return df_train

# %%
compute_uncertainty(df, 'Linear_interpolation', 10)
# Out:
# [0.35818289 0.05298633 0.67581172 0.03832221 0.17726203 0.28020722
#  0.83058758 0.44925622 0.04824315 0.53196198 0.87249024 0.0682281
#  0.37008077 0.38214328 0.25685231 0.61637297 0.99851254 0.64106692
#  0.44476235 0.29076501 0.34270924 0.28781542 0.47956214 0.01394661
#  0.21437278 0.75568639 0.47358102 0.46862615 0.75183987 0.61796092]
# [0.23653807 0.72429597 0.34064304 0.19509173 0.23331509 0.26718009
#  0.26035965 0.9531133  0.08774627 0.6585393  0.48312635 0.08776391
#  0.1320781  0.82172471 0.60904591 0.73696233 0.24205965 0.28380155
#  0.46791407 0.17356061 0.44768144 0.09178393 0.7166907  0.96855504
#  0.8275714  0.49160907 0.79381025 0.7796895  0.95617266 0.59006657]
# [0.20840436 0.6219476  0.96704611 0.97351168 0.83452453 0.56813153
#  0.67399917 0.50360873 0.58527886 0.99502708 0.60659196 0.50407113
#  0.07326821 0.48891346 0.52609486 0.32695837 0.45762754 0.16440795
#  0.1586586  0.47017613 0.16091219 0.00954226 0.43976074 0.50393726
#  0.53409873 0.10054364 0.27697966 0.60319433 0.50615013 0.14747646]
# [0.27751928 0.87841545 0.95125431 0.84456713 0.7507244  0.23425862
#  0.98774534 0.46212423 0.99270507 0.40489576 0.73396612 0.37499973
#  0.68255261 0.47025112 0.11911813 0.75325381 0.19019332 0.90312215
#  0.2037298  0.58929186 0.77386842 0.18387068 0.4833301  0.27583753
#  0.26311324 0.62106742 0.32998863 0.7143618  0.44126469 0.56890216]
# [0.50118574 0.68126443 0.56495395 0.96439514 0.52852313 0.82730724
#  0.08319301 0.36990442 0.8977965  0.85856792 0.4295725  0.8427227
#  0.84135325 0.23030431 0.92370138 0.29872797 0.63301642 0.29773745
#  0.67106959 0.5817739  0.763244   0.25907    0.55691737 0.88722369
#  0.47944928 0.98385936 0.55824957 0.72140046 0.02555093 0.97263701]
# [0.03689877 0.78172545 0.66651787 0.06251705 0.74920753 0.81569431
#  0.4791611  0.7204577  0.11130758 0.36668087 0.08593073 0.83809044
#  0.37780867 0.55058038 0.94793199 0.89631755 0.31210461 0.45228716
#  0.12917896 0.84425865 0.83681464 0.24831083 0.49585555 0.48145326
#  0.86787399 0.25545522 0.90975344 0.3073431  0.50280763 0.83001668]
# [0.54313121 0.44843591 0.31615728 0.60841124 0.44441587 0.56572876
#  0.27251268 0.4469872  0.55759843 0.47226367 0.52164029 0.38039432
#  0.84718645 0.85449904 0.62268379 0.29894164 0.05959882 0.34594625
#  0.28819984 0.50866865 0.41484607 0.6145776  0.1285146  0.47517827
#  0.22761583 0.90290806 0.93781388 0.40478666 0.59023544 0.45175503]
# [6.68355670e-01 1.83440319e-01 3.08174385e-01 4.75782674e-01
#  7.93142393e-01 4.72931997e-01 1.88754680e-01 4.02793342e-01
#  2.78886749e-04 7.74623565e-01 4.60839450e-01 2.46075410e-02
#  1.95176442e-01 8.42229418e-01 9.90496799e-01 6.13586465e-02
#  5.16126245e-01 2.98811681e-01 4.45283185e-01 3.08408603e-01
#  5.38850982e-01 9.49659798e-01 9.23804024e-01 7.37546862e-01
#  5.63986618e-02 8.96220218e-01 8.42546262e-01 6.90468738e-01
#  1.37063423e-01 8.81370286e-01]
# [0.41524023 0.55265334 0.43384177 0.04469555 0.32992461 0.57886621
#  0.20777854 0.72414076 0.65416277 0.55050584 0.89400734 0.6447283
#  0.94764207 0.5430475  0.12277758 0.90834336 0.05319359 0.42931178
#  0.35752673 0.32349932 0.92136377 0.68922591 0.90060568 0.80308764
#  0.59405457 0.71708596 0.10627602 0.02232619 0.01924473 0.17887395]
# [0.3428426  0.46799678 0.85030628 0.99757118 0.00311009 0.47573729
#  0.60291482 0.85837123 0.22508158 0.98177325 0.76795216 0.06650037
#  0.12236247 0.69249026 0.82019415 0.40716316 0.82062643 0.60121741
#  0.5570976  0.87657032 0.93342887 0.80923752 0.00763433 0.84347761
#  0.78452639 0.16475933 0.71840298 0.61657016 0.31342569 0.57612927]
# Mean:  8176.299198751175
# Standard deviation:  4277.276809933769
# Confidence interval:  (-207.1633487190129, 16559.761746221364)
# 4277.276809933769

# %% [markdown]
# ### Obtain and estimate when possible the Methane emissions for the last 10 years in all countries

# %%
df_methane_emission_ten_y = wb.data.DataFrame(['EN.ATM.METH.KT.CE'], mrv=10, columns = 'series').reset_index()

# %% [markdown]
# ### ETL

# %%
DICO_GLOBAL_METHANE = {'EN.ATM.METH.ZG':'GlobalMethane(pct_change)', 
                       'EN.ATM.METH.KT.CE':'GlobalMethane(ktco2)'}

DICO_ENERGY = {'EN.ATM.METH.EG.ZS':'EnergieMethane', 
               'EN.ATM.METH.EG.KT.CE':'EnergieMethane(ktco2)', 
              }
DICO_ENERGY_RELATED = {'IS.AIR.DPRT':'AirTransport', 'EG.USE.ELEC.KH.PC': 'ConsoElec', 
                       'EG.ELC.NGAS.ZS':'EnergieNatualGaz(%total)',
              'EG.FEC.RNEW.ZS':'RenewableConso(%totalconso)', 
                       'EG.USE.COMM.FO.ZS':'FossilfuelConso(%totalconso)',
              'EN.ATM.CO2E.KT': 'CO2Emission(kt)', 
                'EG.USE.PCAP.KG.OE':'PrimaryEnergy(kgoil)', 
                       'EG.USE.CRNW.ZS':'PrimaryEnergy(%total)'}

DICO_AGRICULTURE_METHANE = {'EN.ATM.METH.AG.KT.CE':'AgricultureMethane(ktco2)', 
                    'EN.ATM.METH.AG.ZS':'AgricultureMethane(٪total)'
                   }

DICO_AGRICULTURE_RELATED = {'AG.LND.TOTL.K2':'LandArea(count)' }

# %%
features = ['EN.ATM.METH.EG.ZS','EN.ATM.METH.ZG', 
            'EN.ATM.METH.AG.ZS', 'EN.ATM.METH.AG.KT.CE', 'IS.AIR.DPRT', 
            'EG.USE.ELEC.KH.PC', 'AG.LND.TOTL.K2', 'EN.ATM.METH.AG.KT.CE',
            'EN.ATM.METH.AG.ZS','EN.ATM.METH.EG.KT.CE','EN.ATM.METH.EG.ZS', 
            'EN.ATM.METH.KT.CE', 'EN.ATM.METH.ZG', 'EG.ELC.NGAS.ZS', 'EG.FEC.RNEW.ZS', 
            'EG.USE.COMM.FO.ZS','EN.ATM.CO2E.KT', 'EG.USE.PCAP.KG.OE', 'EG.USE.CRNW.ZS'
           ]

# %%
world_methane_emission = wb.data.DataFrame(features, columns = 'series').reset_index()

# %%
wme_df = pd.read_csv('world_methane_emission.csv', index_col = False)

# %%
wme_df = wme_df.rename(columns={'time':'year'})

# %%
wme_df
# Out:
#        Unnamed: 0 economy  year  LandArea(count)  EnergieNatualGaz(%total)  \
# 0               0     ABW  1960              NaN                       NaN
# 1               1     ABW  1961            180.0                       NaN
# 2               2     ABW  1962            180.0                       NaN
# 3               3     ABW  1963            180.0                       NaN
# 4               4     ABW  1964            180.0                       NaN
# ...           ...     ...   ...              ...                       ...
# 12519       12519     ZWE  2017         386850.0                       NaN
# 12520       12520     ZWE  2018         386850.0                       NaN
# 12521       12521     ZWE  2019         386850.0                       NaN
# 12522       12522     ZWE  2020         386850.0                       NaN
# 12523       12523     ZWE  2021              NaN                       NaN
#
#        RenewableConso(%totalconso)  FossilfuelConso(%totalconso)  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 12519                        82.46                           NaN
# 12520                        80.23                           NaN
# 12521                        81.50                           NaN
# 12522                          NaN                           NaN
# 12523                          NaN                           NaN
#
#        PrimaryEnergy(%total)  ConsoElec  PrimaryEnergy(kgoil)  \
# 0                        NaN        NaN                   NaN
# 1                        NaN        NaN                   NaN
# 2                        NaN        NaN                   NaN
# 3                        NaN        NaN                   NaN
# 4                        NaN        NaN                   NaN
# ...                      ...        ...                   ...
# 12519                    NaN        NaN                   NaN
# 12520                    NaN        NaN                   NaN
# 12521                    NaN        NaN                   NaN
# 12522                    NaN        NaN                   NaN
# 12523                    NaN        NaN                   NaN
#
#        CO2Emission(kt)  AgricultureMethane(ktco2)  AgricultureMethane(٪total)  \
# 0                  NaN                        NaN                         NaN
# 1                  NaN                        NaN                         NaN
# 2                  NaN                        NaN                         NaN
# 3                  NaN                        NaN                         NaN
# 4                  NaN                        NaN                         NaN
# ...                ...                        ...                         ...
# 12519     10340.000153                     6250.0                         NaN
# 12520     12380.000114                     6420.0                         NaN
# 12521     11760.000229                     6540.0                         NaN
# 12522              NaN                        NaN                         NaN
# 12523              NaN                        NaN                         NaN
#
#        EnergieMethane(ktco2)  EnergieMethane  GlobalMethane(ktco2)  \
# 0                        NaN             NaN                   NaN
# 1                        NaN             NaN                   NaN
# 2                        NaN             NaN                   NaN
# 3                        NaN             NaN                   NaN
# 4                        NaN             NaN                   NaN
# ...                      ...             ...                   ...
# 12519                 2970.0             NaN          12060.000420
# 12520                 3020.0             NaN          12340.000153
# 12521                 3070.0             NaN          12550.000191
# 12522                    NaN             NaN                   NaN
# 12523                    NaN             NaN                   NaN
#
#        GlobalMethane(pct_change)  AirTransport  meth_valuebylandaera
# 0                            NaN           NaN                   NaN
# 1                            NaN           NaN                   NaN
# 2                            NaN           NaN                   NaN
# 3                            NaN           NaN                   NaN
# 4                            NaN           NaN                   NaN
# ...                          ...           ...                   ...
# 12519                        NaN        3444.0              0.031175
# 12520                        NaN        3444.0              0.031899
# 12521                        NaN           NaN              0.032442
# 12522                        NaN        3450.0                   NaN
# 12523                        NaN           NaN                   NaN
#
# [12524 rows x 19 columns]

# %% [markdown]
# ### Notation

# %%
def compute_score(df, group, col = 'meth_valuebylandaera'):
    #compute max value methan emission by year
    dfgrouped = pd.DataFrame(df.groupby(group)[col].max()).reset_index()
    dfgrouped = dfgrouped.rename(columns={col: 'max_meth'})
    df = df.merge(dfgrouped, on=[group], how='left')
    
    #compute min value methan emission by year
    dfgrouped = pd.DataFrame(df.groupby(group)[col].min()).reset_index()
    dfgrouped = dfgrouped.rename(columns={col: 'min_meth'})
    df = df.merge(dfgrouped, on=[group], how='left')
    # scale the score between 0 to 4 by using min=max scaler method
    df[f'note_{group}']= np.where(df[col].notnull(), 
                              4*(df[col] - df['min_meth'])/
                              (df['max_meth'] - df['min_meth']), np.nan)
    del df['max_meth']
    del df['min_meth']
    return df

# %%
wme_df = compute_score(wme_df, 'year')

# %% [markdown]
# #### cleaning columns

# %%
del wme_df['Unnamed: 0']

# %%
columns_rename_list = [DICO_GLOBAL_METHANE, DICO_ENERGY, DICO_ENERGY_RELATED, 
                  DICO_AGRICULTURE_METHANE, DICO_AGRICULTURE_RELATED]

# %%
dico_final = {}
for dico in columns_rename_list:
    dico_final.update(dico)

# %%
wme_df.corr()
# Out:
#                                   year  LandArea(count)  \
# year                          1.000000        -0.001494
# LandArea(count)              -0.001494         1.000000
# EnergieNatualGaz(%total)      0.225361        -0.023877
# RenewableConso(%totalconso)  -0.041511        -0.054802
# FossilfuelConso(%totalconso) -0.078281         0.105977
# PrimaryEnergy(%total)        -0.088850        -0.055177
# ConsoElec                     0.170940         0.127586
# PrimaryEnergy(kgoil)          0.068652         0.148067
# CO2Emission(kt)               0.037499         0.598734
# AgricultureMethane(ktco2)     0.011934         0.581925
# AgricultureMethane(٪total)   -0.075118         0.002863
# EnergieMethane(ktco2)         0.039646         0.769319
# EnergieMethane                0.036698         0.179202
# GlobalMethane(ktco2)          0.025416         0.782438
# GlobalMethane(pct_change)     0.130507        -0.036939
# AirTransport                  0.075771         0.480554
# meth_valuebylandaera          0.034430        -0.062697
# note_year                    -0.051351        -0.067002
#
#                               EnergieNatualGaz(%total)  \
# year                                          0.225361
# LandArea(count)                              -0.023877
# EnergieNatualGaz(%total)                      1.000000
# RenewableConso(%totalconso)                  -0.374529
# FossilfuelConso(%totalconso)                  0.346475
# PrimaryEnergy(%total)                        -0.263584
# ConsoElec                                     0.153079
# PrimaryEnergy(kgoil)                          0.395811
# CO2Emission(kt)                              -0.027967
# AgricultureMethane(ktco2)                    -0.063808
# AgricultureMethane(٪total)                   -0.418832
# EnergieMethane(ktco2)                         0.073005
# EnergieMethane                                0.510186
# GlobalMethane(ktco2)                          0.006899
# GlobalMethane(pct_change)                     0.312124
# AirTransport                                 -0.004743
# meth_valuebylandaera                          0.284929
# note_year                                     0.289344
#
#                               RenewableConso(%totalconso)  \
# year                                            -0.041511
# LandArea(count)                                 -0.054802
# EnergieNatualGaz(%total)                        -0.374529
# RenewableConso(%totalconso)                      1.000000
# FossilfuelConso(%totalconso)                    -0.827692
# PrimaryEnergy(%total)                            0.923787
# ConsoElec                                       -0.273095
# PrimaryEnergy(kgoil)                            -0.411564
# CO2Emission(kt)                                 -0.142409
# AgricultureMethane(ktco2)                        0.003484
# AgricultureMethane(٪total)                       0.431197
# EnergieMethane(ktco2)                           -0.160698
# EnergieMethane                                  -0.044853
# GlobalMethane(ktco2)                            -0.092789
# GlobalMethane(pct_change)                       -0.027521
# AirTransport                                    -0.130958
# meth_valuebylandaera                            -0.166160
# note_year                                       -0.173062
#
#                               FossilfuelConso(%totalconso)  \
# year                                             -0.078281
# LandArea(count)                                   0.105977
# EnergieNatualGaz(%total)                          0.346475
# RenewableConso(%totalconso)                      -0.827692
# FossilfuelConso(%totalconso)                      1.000000
# PrimaryEnergy(%total)                            -0.888778
# ConsoElec                                         0.194843
# PrimaryEnergy(kgoil)                              0.366047
# CO2Emission(kt)                                   0.159551
# AgricultureMethane(ktco2)                         0.045932
# AgricultureMethane(٪total)                       -0.357586
# EnergieMethane(ktco2)                             0.165217
# EnergieMethane                                    0.312318
# GlobalMethane(ktco2)                              0.135278
# GlobalMethane(pct_change)                        -0.026944
# AirTransport                                      0.108735
# meth_valuebylandaera                              0.099502
# note_year                                         0.103518
#
#                               PrimaryEnergy(%total)  ConsoElec  \
# year                                      -0.088850   0.170940
# LandArea(count)                           -0.055177   0.127586
# EnergieNatualGaz(%total)                  -0.263584   0.153079
# RenewableConso(%totalconso)                0.923787  -0.273095
# FossilfuelConso(%totalconso)              -0.888778   0.194843
# PrimaryEnergy(%total)                      1.000000  -0.418362
# ConsoElec                                 -0.418362   1.000000
# PrimaryEnergy(kgoil)                      -0.457091   0.810961
# CO2Emission(kt)                           -0.129914   0.126274
# AgricultureMethane(ktco2)                  0.045498  -0.056641
# AgricultureMethane(٪total)                 0.386604  -0.225988
# EnergieMethane(ktco2)                     -0.112704   0.051868
# EnergieMethane                            -0.235158   0.084477
# GlobalMethane(ktco2)                      -0.046390   0.006649
# GlobalMethane(pct_change)                 -0.040229   0.114412
# AirTransport                              -0.120328   0.231695
# meth_valuebylandaera                      -0.109976   0.286121
# note_year                                 -0.115436   0.289642
#
#                               PrimaryEnergy(kgoil)  CO2Emission(kt)  \
# year                                      0.068652         0.037499
# LandArea(count)                           0.148067         0.598734
# EnergieNatualGaz(%total)                  0.395811        -0.027967
# RenewableConso(%totalconso)              -0.411564        -0.142409
# FossilfuelConso(%totalconso)              0.366047         0.159551
# PrimaryEnergy(%total)                    -0.457091        -0.129914
# ConsoElec                                 0.810961         0.126274
# PrimaryEnergy(kgoil)                      1.000000         0.138583
# CO2Emission(kt)                           0.138583         1.000000
# AgricultureMethane(ktco2)                -0.053045         0.612203
# AgricultureMethane(٪total)               -0.360668        -0.067177
# EnergieMethane(ktco2)                     0.100643         0.832964
# EnergieMethane                            0.338813         0.143707
# GlobalMethane(ktco2)                      0.039398         0.842451
# GlobalMethane(pct_change)                 0.172051        -0.030234
# AirTransport                              0.221569         0.765877
# meth_valuebylandaera                      0.314726        -0.024179
# note_year                                 0.318916        -0.026914
#
#                               AgricultureMethane(ktco2)  \
# year                                           0.011934
# LandArea(count)                                0.581925
# EnergieNatualGaz(%total)                      -0.063808
# RenewableConso(%totalconso)                    0.003484
# FossilfuelConso(%totalconso)                   0.045932
# PrimaryEnergy(%total)                          0.045498
# ConsoElec                                     -0.056641
# PrimaryEnergy(kgoil)                          -0.053045
# CO2Emission(kt)                                0.612203
# AgricultureMethane(ktco2)                      1.000000
# AgricultureMethane(٪total)                     0.150323
# EnergieMethane(ktco2)                          0.514715
# EnergieMethane                                 0.002127
# GlobalMethane(ktco2)                           0.855711
# GlobalMethane(pct_change)                     -0.028069
# AirTransport                                   0.406416
# meth_valuebylandaera                          -0.043890
# note_year                                     -0.046276
#
#                               AgricultureMethane(٪total)  \
# year                                           -0.075118
# LandArea(count)                                 0.002863
# EnergieNatualGaz(%total)                       -0.418832
# RenewableConso(%totalconso)                     0.431197
# FossilfuelConso(%totalconso)                   -0.357586
# PrimaryEnergy(%total)                           0.386604
# ConsoElec                                      -0.225988
# PrimaryEnergy(kgoil)                           -0.360668
# CO2Emission(kt)                                -0.067177
# AgricultureMethane(ktco2)                       0.150323
# AgricultureMethane(٪total)                      1.000000
# EnergieMethane(ktco2)                          -0.195339
# EnergieMethane                                 -0.485575
# GlobalMethane(ktco2)                           -0.010591
# GlobalMethane(pct_change)                      -0.152372
# AirTransport                                   -0.069904
# meth_valuebylandaera                           -0.257162
# note_year                                      -0.264554
#
#                               EnergieMethane(ktco2)  EnergieMethane  \
# year                                       0.039646        0.036698
# LandArea(count)                            0.769319        0.179202
# EnergieNatualGaz(%total)                   0.073005        0.510186
# RenewableConso(%totalconso)               -0.160698       -0.044853
# FossilfuelConso(%totalconso)               0.165217        0.312318
# PrimaryEnergy(%total)                     -0.112704       -0.235158
# ConsoElec                                  0.051868        0.084477
# PrimaryEnergy(kgoil)                       0.100643        0.338813
# CO2Emission(kt)                            0.832964        0.143707
# AgricultureMethane(ktco2)                  0.514715        0.002127
# AgricultureMethane(٪total)                -0.195339       -0.485575
# EnergieMethane(ktco2)                      1.000000        0.294015
# EnergieMethane                             0.294015        1.000000
# GlobalMethane(ktco2)                       0.874296        0.158501
# GlobalMethane(pct_change)                 -0.013672        0.215719
# AirTransport                               0.546939        0.072879
# meth_valuebylandaera                      -0.028896       -0.059408
# note_year                                 -0.032974       -0.066917
#
#                               GlobalMethane(ktco2)  GlobalMethane(pct_change)  \
# year                                      0.025416                   0.130507
# LandArea(count)                           0.782438                  -0.036939
# EnergieNatualGaz(%total)                  0.006899                   0.312124
# RenewableConso(%totalconso)              -0.092789                  -0.027521
# FossilfuelConso(%totalconso)              0.135278                  -0.026944
# PrimaryEnergy(%total)                    -0.046390                  -0.040229
# ConsoElec                                 0.006649                   0.114412
# PrimaryEnergy(kgoil)                      0.039398                   0.172051
# CO2Emission(kt)                           0.842451                  -0.030234
# AgricultureMethane(ktco2)                 0.855711                  -0.028069
# AgricultureMethane(٪total)               -0.010591                  -0.152372
# EnergieMethane(ktco2)                     0.874296                  -0.013672
# EnergieMethane                            0.158501                   0.215719
# GlobalMethane(ktco2)                      1.000000                  -0.025896
# GlobalMethane(pct_change)                -0.025896                   1.000000
# AirTransport                              0.586103                  -0.035298
# meth_valuebylandaera                     -0.035393                   0.041710
# note_year                                -0.039003                   0.025593
#
#                               AirTransport  meth_valuebylandaera  note_year
# year                              0.075771              0.034430  -0.051351
# LandArea(count)                   0.480554             -0.062697  -0.067002
# EnergieNatualGaz(%total)         -0.004743              0.284929   0.289344
# RenewableConso(%totalconso)      -0.130958             -0.166160  -0.173062
# FossilfuelConso(%totalconso)      0.108735              0.099502   0.103518
# PrimaryEnergy(%total)            -0.120328             -0.109976  -0.115436
# ConsoElec                         0.231695              0.286121   0.289642
# PrimaryEnergy(kgoil)              0.221569              0.314726   0.318916
# CO2Emission(kt)                   0.765877             -0.024179  -0.026914
# AgricultureMethane(ktco2)         0.406416             -0.043890  -0.046276
# AgricultureMethane(٪total)       -0.069904             -0.257162  -0.264554
# EnergieMethane(ktco2)             0.546939             -0.028896  -0.032974
# EnergieMethane                    0.072879             -0.059408  -0.066917
# GlobalMethane(ktco2)              0.586103             -0.035393  -0.039003
# GlobalMethane(pct_change)        -0.035298              0.041710   0.025593
# AirTransport                      1.000000             -0.014510  -0.018924
# meth_valuebylandaera             -0.014510              1.000000   0.932923
# note_year                        -0.018924              0.932923   1.000000

# %%
import matplotlib.pyplot as plt

plt.matshow(wme_df.corr())
plt.show()

# %%
##Feature selection based on correlation

# %%
predictors = ['GlobalMethane(ktco2)', 'LandArea(count)', 'CO2Emission(kt)', 'AgricultureMethane(ktco2)',
              'EnergieMethane(ktco2)', 'AirTransport', 'note_year', 'meth_valuebylandaera']
# predictors = ['GlobalMethane(ktco2)', 'CO2Emission(kt)', 'AgricultureMethane(ktco2)','EnergieMethane(ktco2)', 'AirTransport', 'note_year']
feature_selected = ['economy', 'year'] + predictors

# %%
wme_df_final = wme_df[feature_selected]

# %%
wme_df_final
# Out:
#       economy  year  GlobalMethane(ktco2)  LandArea(count)  CO2Emission(kt)  \
# 0         ABW  1960                   NaN              NaN              NaN
# 1         ABW  1961                   NaN            180.0              NaN
# 2         ABW  1962                   NaN            180.0              NaN
# 3         ABW  1963                   NaN            180.0              NaN
# 4         ABW  1964                   NaN            180.0              NaN
# ...       ...   ...                   ...              ...              ...
# 12519     ZWE  2017          12060.000420         386850.0     10340.000153
# 12520     ZWE  2018          12340.000153         386850.0     12380.000114
# 12521     ZWE  2019          12550.000191         386850.0     11760.000229
# 12522     ZWE  2020                   NaN         386850.0              NaN
# 12523     ZWE  2021                   NaN              NaN              NaN
#
#        AgricultureMethane(ktco2)  EnergieMethane(ktco2)  AirTransport  \
# 0                            NaN                    NaN           NaN
# 1                            NaN                    NaN           NaN
# 2                            NaN                    NaN           NaN
# 3                            NaN                    NaN           NaN
# 4                            NaN                    NaN           NaN
# ...                          ...                    ...           ...
# 12519                     6250.0                 2970.0        3444.0
# 12520                     6420.0                 3020.0        3444.0
# 12521                     6540.0                 3070.0           NaN
# 12522                        NaN                    NaN        3450.0
# 12523                        NaN                    NaN           NaN
#
#        note_year  meth_valuebylandaera
# 0            NaN                   NaN
# 1            NaN                   NaN
# 2            NaN                   NaN
# 3            NaN                   NaN
# 4            NaN                   NaN
# ...          ...                   ...
# 12519   0.005856              0.031175
# 12520   0.005889              0.031899
# 12521   0.005836              0.032442
# 12522        NaN                   NaN
# 12523        NaN                   NaN
#
# [12524 rows x 10 columns]

# %% [markdown]
# ### Note by cluster

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from IPython.display import clear_output

def plot_clusters(data, labels, centroids):
    pca = PCA(n_components=2)
    data_2d = pca.fit_transform(data)
    centroids_2d = pca.transform(centroids.T)
    clear_output(wait=True)
    plt.scatter(x=data_2d[:,0], y=data_2d[:,1], c=labels)
    plt.scatter(x=centroids_2d[:,0], y=centroids_2d[:,1])
    plt.show()

# %%
@dataclass
class kmeans_model :
    CountryAlpha2Code : str
    year : str
    df: pd.DataFrame
    
    def preprocessing(self):
        
        self.df = self.df[self.df['year'] == min(float(self.year), CURRENT_YEAR_AVAILABLE)]
        self.df = self.df.dropna(subset=self.df.columns)
#         self.df = self.df.reset_index()
        data = self.df[PREDICTORS].copy()
        #normalization between 0 to 4
        data = ((data - data.min()) / (data.max() - data.min())) * 3 + 1
        
        print(data.describe)
        
        return data
    
    def model_train(self, k):
        kmeans = KMeans(k)
        kmeans.fit(self.preprocessing())
        return kmeans
        
        
    def compute_labels_centroids(self, k):
        labels = self.model_train(k).labels_
        centroids = self.model_train(k).cluster_centers_
        return labels, centroids

# %%
PREDICTORS = ['GlobalMethane(ktco2)', 'LandArea(count)', 'CO2Emission(kt)',
              'AgricultureMethane(ktco2)','EnergieMethane(ktco2)', 
              'AirTransport', 'note_year'
            ]

# %%
model = kmeans_model('FRA', 2009, wme_df_final)

# %%
def cluster_score(CountryAlphaCode, year, df):
    if type(year) != int :
        raise Exception('the year should be numerical value')

    model = kmeans_model(CountryAlphaCode, year, df)
    data = model.preprocessing()
    labels, centroids = model.compute_labels_centroids(4)
    plot_clusters(data, labels, centroids.T)
    labels = pd.DataFrame(labels, columns = ['labels'])
    df = df.merge(labels, left_index=True, right_index=True)
    df = compute_score(df, 'labels', 'meth_valuebylandaera')
    avg_by_cluster = df.groupby(['labels'], as_index=False).agg(
                      {'GlobalMethane(ktco2)':['mean','std'], 'note_year':['first']})

    avg_by_cluster.columns = ['labels'] + ['_'.join(col) for col in avg_by_cluster.columns.values[1:]]
    avg_by_cluster = avg_by_cluster.rename(columns={'GlobalMethane(ktco2)_mean' : 'Methane_emission_estimated',
                               'GlobalMethane(ktco2)_std': 'uncertainty',
                               'note_year_first': 'score_cluster'})

    df = df.merge(avg_by_cluster, how='left', on='labels')

    return df

# %%
cluster_score('FRA', 2009, wme_df_final)
# Out:
#     economy  year  GlobalMethane(ktco2)  LandArea(count)  CO2Emission(kt)  \
# 0       ABW  1960                   NaN              NaN              NaN
# 1       ABW  1961                   NaN            180.0              NaN
# 2       ABW  1962                   NaN            180.0              NaN
# 3       ABW  1963                   NaN            180.0              NaN
# 4       ABW  1964                   NaN            180.0              NaN
# ..      ...   ...                   ...              ...              ...
# 118     AFG  2016          15829.999924         652230.0      5300.000191
# 119     AFG  2017          15609.999657         652230.0      4780.000210
# 120     AFG  2018          15909.999847         652230.0      6070.000172
# 121     AFG  2019          16370.000839         652230.0      6079.999924
# 122     AFG  2020                   NaN         652230.0              NaN
#
#      AgricultureMethane(ktco2)  EnergieMethane(ktco2)  AirTransport  \
# 0                          NaN                    NaN           NaN
# 1                          NaN                    NaN           NaN
# 2                          NaN                    NaN           NaN
# 3                          NaN                    NaN           NaN
# 4                          NaN                    NaN           NaN
# ..                         ...                    ...           ...
# 118                    10630.0                 2190.0     22770.000
# 119                    10330.0                 2210.0     24207.000
# 120                    10540.0                 2220.0     10454.000
# 121                    10920.0                 2230.0      7334.000
# 122                        NaN                    NaN      4635.714
#
#      note_year  meth_valuebylandaera  labels  note_labels  \
# 0          NaN                   NaN       1          NaN
# 1          NaN                   NaN       1          NaN
# 2          NaN                   NaN       1          NaN
# 3          NaN                   NaN       1          NaN
# 4          NaN                   NaN       1          NaN
# ..         ...                   ...     ...          ...
# 118   0.004657              0.024271       1     3.775701
# 119   0.004496              0.023933       1     3.684319
# 120   0.004503              0.024393       1     3.808930
# 121   0.004515              0.025099       1     4.000000
# 122        NaN                   NaN       1          NaN
#
#      Methane_emission_estimated  uncertainty  score_cluster
# 0                  11634.285688  3300.063345       0.005917
# 1                  11634.285688  3300.063345       0.005917
# 2                  11634.285688  3300.063345       0.005917
# 3                  11634.285688  3300.063345       0.005917
# 4                  11634.285688  3300.063345       0.005917
# ..                          ...          ...            ...
# 118                11634.285688  3300.063345       0.005917
# 119                11634.285688  3300.063345       0.005917
# 120                11634.285688  3300.063345       0.005917
# 121                11634.285688  3300.063345       0.005917
# 122                11634.285688  3300.063345       0.005917
#
# [123 rows x 15 columns]
