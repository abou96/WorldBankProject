# %%
# !pip install wbgapi
# Out:
# Requirement already satisfied: wbgapi in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (1.0.12)
# Requirement already satisfied: PyYAML in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from wbgapi) (6.0)
# Requirement already satisfied: requests in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from wbgapi) (2.28.1)
# Requirement already satisfied: tabulate in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from wbgapi) (0.9.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests->wbgapi) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests->wbgapi) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests->wbgapi) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/mac/.pyenv/versions/3.10.3/lib/python3.10/site-packages (from requests->wbgapi) (2.1.1)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/mac/.pyenv/versions/3.10.3/bin/python3.10 -m pip install --upgrade pip' command.

# %%
import wbgapi as wb
import pandas as pd
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import matplotlib
from datetime import datetime
from dataclasses import dataclass

# %%
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# ### Query the environmental score, methane emission (kt of CO2 equivalent)
# - #### Methane emissions from energy processes are emissions from the production, handling, transmission, and combustion of fossil fuels and biofuels.
# - #### At standard temperature and pressure, one metric ton of carbon dioxide (CO₂) would fill a sphere 32 feet (about 9.8 meters) in diameter. The average car in the U.S. will produce this over a three-month period.

# %%
wb.series.info(q='electricity')
# Out:
# id                 value
# -----------------  --------------------------------------------------------------------------------------
# EG.ELC.ACCS.RU.ZS  Access to electricity, rural (% of rural population)
# EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban population)
# EG.ELC.ACCS.ZS     Access to electricity (% of population)
# EG.ELC.COAL.ZS     Electricity production from coal sources (% of total)
# EG.ELC.FOSL.ZS     Electricity production from oil, gas and coal sources (% of total)
# EG.ELC.HYRO.ZS     Electricity production from hydroelectric sources (% of total)
# EG.ELC.NGAS.ZS     Electricity production from natural gas sources (% of total)
# EG.ELC.NUCL.ZS     Electricity production from nuclear sources (% of total)
# EG.ELC.PETR.ZS     Electricity production from oil sources (% of total)
# EG.ELC.RNEW.ZS     Renewable electricity output (% of total electricity output)
# EG.ELC.RNWX.KH     Electricity production from renewable sources, excluding hydroelectric (kWh)
# EG.ELC.RNWX.ZS     Electricity production from renewable sources, excluding hydroelectric (% of total)
# EN.CO2.ETOT.ZS     CO2 emissions from electricity and heat production, total (% of total fuel combustion)
# IC.ELC.TIME        Time required to get electricity (days)
#                    14 elements

# %%
wb.series.info(q='Renewable')
# Out:
# id              value
# --------------  -----------------------------------------------------------------------------------
# EG.ELC.RNEW.ZS  Renewable electricity output (% of total electricity output)
# EG.ELC.RNWX.KH  Electricity production from renewable sources, excluding hydroelectric (kWh)
# EG.ELC.RNWX.ZS  Electricity production from renewable sources, excluding hydroelectric (% of total)
# EG.FEC.RNEW.ZS  Renewable energy consumption (% of total final energy consumption)
# EG.USE.CRNW.ZS  Combustible renewables and waste (% of total energy)
# ER.H2O.INTR.K3  Renewable internal freshwater resources, total (billion cubic meters)
# ER.H2O.INTR.PC  Renewable internal freshwater resources per capita (cubic meters)
#                 7 elements

# %% [markdown]
# - NY.GDP.PCAP.CD	GDP per capita (current US)
# - IS.AIR.DPRT	Air transport, registered carrier departures worldwide
# - EG.USE.ELEC.KH.PC	Electric power consumption (kWh per capita)
# - AG.LND.TOTL.K2	 Land area (sq. km)
# - EN.ATM.METH.AG.KT.CE and EN.ATM.METH.AG.ZS : Agricultural methane emissions are emissions from animals, animal waste, rice production, agricultural waste burning (nonenergy, on-site), and savanna burning.
# - EN.ATM.METH.EG.KT.CE and EN.ATM.METH.EG.ZS : Methane emissions from energy processes are emissions from the production, handling, transmission, and combustion of fossil fuels and biofuels.
# - EN.ATM.METH.KT.CE and EN.ATM.METH.ZG: Methane emissions are those stemming from human activities such as agriculture and from industrial methane production.
# - EG.ELC.NGAS.ZS	Electricity production from natural gas sources (% of total)
# - EG.FEC.RNEW.ZS	Renewable energy consumption (% of total final energy consumption)
# - EG.USE.COMM.FO.ZS	Fossil fuel energy consumption (% of total)

# %%
QUERY_ID = ['EN.ATM.METH.EG.KT.CE']

features = ['EN.ATM.METH.EG.ZS','EN.ATM.METH.ZG', 
            'EN.ATM.METH.AG.ZS', 'EN.ATM.METH.AG.KT.CE',
           'NY.GDP.PCAP.CD', 'IS.AIR.DPRT', 'EG.USE.ELEC.KH.PC', 'AG.LND.TOTL.K2', 
            'EN.ATM.METH.AG.KT.CE', 'EN.ATM.METH.AG.ZS','EN.ATM.METH.EG.KT.CE', 'EN.ATM.METH.EG.ZS', 
            'EN.ATM.METH.KT.CE', 'EN.ATM.METH.ZG', 'EG.ELC.NGAS.ZS', 'EG.FEC.RNEW.ZS', 'EG.USE.COMM.FO.ZS',
            'EN.ATM.CO2E.KT', 'EG.USE.PCAP.KG.OE', 'EG.USE.CRNW.ZS'
           ]

CURRENT_YEAR_AVAILABLE = 2021

# %% [markdown]
# #### GET OUR DATA FROM WORLD BANK API
#
# We retrieve the data from the API using CountryAlpha2Code and the period time
# - CountryAlpha2Code : later.....
# - period time : later....

# %%
def HandlingPeriodFormatInput(period_time) :
    
    if not isinstance(period_time, list):      
        raise Exception ("period time should be in a format list like this : [2021]")

    if len(period_time) > 3 :
        raise Exception ("The format given is not correct try this format [initial date, final date, step")
        
    if len(period_time) == 2 :
        period_time.insert(2, 1)
        warnings.warn("the format should be [initial date, final date, step")

    if max(period_time) > CURRENT_YEAR_AVAILABLE + 1 or min(period_time) > CURRENT_YEAR_AVAILABLE:

        new_period_time = range(min(2021, period_time[0]), min(2022, period_time[1]), period_time[2])
    else :
         new_period_time = range(period_time[0], period_time[1], period_time[2])

    return new_period_time

# %%
HandlingPeriodFormatInput([2010, 2026, 1])
# Out:
# range(2010, 2022)

# %%
@dataclass
class Country : 
    name : str
    CountryAlpha2Code : str
    period_time : list
    query_id : list

    def queryMethaneData(self) -> pd.DataFrame : #getDataMethEmissionByCountryAndYears
        period_time_range = HandlingPeriodFormatInput(self.period_time)
        df = wb.data.DataFrame(self.query_id, self.CountryAlpha2Code, time = period_time_range, columns='series')   
        return df.reset_index()
    
    def plot(self):
        self.queryMethaneData().set_index('time').plot()

# %%
country = Country('sen', 'MAR', [1960, 2026, 1], QUERY_ID)
data_country = country.queryMethaneData()
country.plot()

# %% [markdown]
# #### DATA PREPROCESSING

# %%
@dataclass
class DataMethCountryPreprocessing :
    
    country : Country
    df: pd.DataFrame


    def CleaningAndRename(self):
        self.df['date'] = self.df['time'].str[2:]
        self.df['date'] = pd.to_datetime(self.df['date'])
        self.df = self.df.rename(columns = {'EN.ATM.METH.EG.KT.CE' : 'ktofCO2'})
        del self.df['time']
        self.df = self.df.set_index('date')

    def MissingValue(self) :
        print(len(self.df[self.df.isnull()]))
        return sns.heatmap(self.df.isnull(),yticklabels=False,cbar=True,cmap='viridis')

    def HandlingFormatDateIndex(self) :
        BeginYear, LastYearToPredict,_ = self.country.period_time
        start = str(BeginYear) + "-01-01"
        end = str(LastYearToPredict) + "-01-01"
        dates = pd.date_range(start=start,end=end)
        self.df= self.df.reindex(dates, fill_value=0)
        self.df = self.df.resample('Y').sum()

# %%
DMCP = DataMethCountryPreprocessing(France, df_France)
DMCP.CleaningAndRename()
DMCP.MissingValue()
DMCP.HandlingFormatDateIndex()
# Out:
# 62

# %%
df = DMCP.df
df.replace(0.0, pd.np.nan, inplace=True)
df.head()
# Out:
#             ktofCO2
# 1960-12-31      NaN
# 1961-12-31      NaN
# 1962-12-31      NaN
# 1963-12-31      NaN
# 1964-12-31      NaN

# %% [markdown]
# ### Handling Missing data

# %%
df['ktofCO2'].hist(bins=30,color='darkred',alpha=0.3)
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='ktofCO2',data=df,palette='winter')
# Out:
# <AxesSubplot: xlabel='ktofCO2'>

# %% [markdown]
# #### 1ere METHOD USING SIMPLE STATISTICAL METHOD such as mean, nedian, mode

# %%
def imput_simple_mean(value_cols, kind= 'mean'):
    
    if pd.isnull(value_cols):
        if kind == 'mean' :
            return df['ktofCO2'].mean()
        elif kind == 'median' :
            return df['ktofCO2'].median()
        elif kind == 'mode' :
            return df['ktofCO2'].mode()[0]
            
    else:
        return value_cols

# %% [markdown]
# ### KnnImputer

# %%
def imputwithKNNImputer(df, col, k):
    imputer = KNNImputer(n_neighbors= k)
    imputed_data = imputer.fit_transform(df)
    imputed = pd.DataFrame(imputed_data, 
                           columns = [col, 'col1', 'col2'])
    imputed.index = df.index
    
    df[col + 'KNNImputer'] = np.where(df[col].isna(), imputed[col], df[col])
    
    return df

# %%
def HandlingMissingValue(df, col, method = 'statistic', k=3):
    if method == 'statistic' :
        for kind in ['mean', 'median', 'mode']:
            df[col + method] = df[col].apply(lambda x: imput_simple_mean(x, kind))
            df[col + method].plot(figsize=(15, 6), title = kind, colormap='jet')
            plt.show()
    if method == 'linear_interpolation':
        df[col + method] = df[col].interpolate(method='linear')
        df[col + method].plot(figsize=(15, 6), title= method, colormap='jet')
        plt.show()
    if method == 'KNNImputer':
        df = imputwithKNNImputer(df, col, k)
        df[col + method].plot(figsize=(15, 6), title= method, colormap='jet')
        plt.show()

# %%
HandlingMissingValue(df, 'ktofCO2', method = 'statistic')

# %%
HandlingMissingValue(df, 'ktofCO2', method = 'linear_interpolation')

# %%
HandlingMissingValue(df, 'ktofCO2', method = 'KNNImputer')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [709], in <cell line: 1>()
# ----> 1 HandlingMissingValue(df, 'ktofCO2', method = 'KNNImputer')
#
# Input In [703], in HandlingMissingValue(df, col, method, k)
#      10     plt.show()
#      11 if method == 'KNNImputer':
# ---> 12     df = imputwithKNNImputer(df, col, k)
#      13     df[col + method].plot(figsize=(15, 6), title= method, colormap='jet')
#      14     plt.show()
#
# Input In [702], in imputwithKNNImputer(df, col, k)
#       2 imputer = KNNImputer(n_neighbors= k)
#       3 imputed_data = imputer.fit_transform(df)
# ----> 4 imputed = pd.DataFrame(imputed_data,
#       5                        columns = [col, 'col1', 'col2'])
#       6 imputed.index = df.index
#       8 df[col + 'KNNImputer'] = np.where(df[col].isna(), imputed[col], df[col])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:694, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     684         mgr = dict_to_mgr(
#     685             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     686             # attribute "name"
#    (...)
#     691             typ=manager,
#     692         )
#     693     else:
# --> 694         mgr = ndarray_to_mgr(
#     695             data,
#     696             index,
#     697             columns,
#     698             dtype=dtype,
#     699             copy=copy,
#     700             typ=manager,
#     701         )
#     703 # For data is list-like, or Iterable (will consume into list)
#     704 elif is_list_like(data):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:351, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     346 # _prep_ndarray ensures that values.ndim == 2 at this point
#     347 index, columns = _get_axes(
#     348     values.shape[0], values.shape[1], index=index, columns=columns
#     349 )
# --> 351 _check_values_indices_shape_match(values, index, columns)
#     353 if typ == "array":
#     355     if issubclass(values.dtype.type, str):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:422, in _check_values_indices_shape_match(values, index, columns)
#     420 passed = values.shape
#     421 implied = (len(index), len(columns))
# --> 422 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (67, 4), indices imply (67, 3)

# %%
#### 2eme METHOD : ML

# %%
#### 2eme METHOD : Custom imputation: KMEANS + STATISTICAL METHOD
predictors = predictors_id + QUERY_ID

# %%
#world_methane_emission = wb.data.DataFrame(predictors, columns = 'series').reset_index()

# %%
#world_methane_emission.to_csv('world_methane_emission.csv')

# %%
#world_methane_emission.head()

# %%
wme_df = pd.read_csv('world_methane_emission.csv', index_col = False)

# %%
wme_df_origin = wme_df.copy()

# %% [markdown]
# #### Data cleaning

# %%
wme_df['time_code'] = wme_df['time'].astype("category").cat.codes

# %%
wme_df['time_code']
# Out:
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#          ..
# 16487    57
# 16488    58
# 16489    59
# 16490    60
# 16491    61
# Name: time_code, Length: 16492, dtype: int8

# %%
features = list(wme_df.columns)[3:]
features_2 = ['EN.ATM.METH.AG.KT.CE','EN.ATM.METH.ZG', 'time_code' ]

features_3 = ['EN.ATM.METH.AG.KT.CE', 'EN.ATM.METH.ZG']

# %%
list_features = [features, features_2, features_3]

# %%
wme_df = wme_df.dropna(subset=features_2)
wme_df = wme_df.reset_index()

# %%
data = wme_df[features_2].copy()
data
# Out:
#       EN.ATM.METH.AG.KT.CE  EN.ATM.METH.ZG  time_code
# 0                   5610.0        0.976719         31
# 1                   5670.0       -3.173352         32
# 2                   5720.0       -2.001814         33
# 3                   5930.0        0.515891         34
# 4                   6250.0        3.385871         35
# ...                    ...             ...        ...
# 5071                6410.0      -17.561159         48
# 5072                6810.0      -18.317977         49
# 5073                7280.0      -17.897641         50
# 5074                7560.0      -17.076618         51
# 5075                7250.0      -16.255594         52
#
# [5076 rows x 3 columns]

# %% [markdown]
# #### Normalisation de la data

# %%
data = ((data - data.min()) / (data.max() - data.min())) * 3 + 1

# %%
data.describe()
# Out:
#        EN.ATM.METH.AG.KT.CE  EN.ATM.METH.ZG    time_code
# count           5076.000000     5076.000000  5076.000000
# mean               1.127770        1.143671     2.501351
# std                0.365961        0.140716     0.906060
# min                1.000000        1.000000     1.000000
# 25%                1.000910        1.110660     1.714286
# 50%                1.005368        1.127225     2.571429
# 75%                1.037947        1.151697     3.285714
# max                4.000000        4.000000     4.000000

# %%
SSE = []

for cluster in range(1,10):
    kmeans = KMeans(n_clusters = cluster, init='k-means++')
    kmeans.fit(data)
    SSE.append(kmeans.inertia_)

# converting the results into a dataframe and plotting them

frame = pd.DataFrame({'Cluster':range(1,10), 'SSE':SSE})
plt.figure(figsize=(12,6))
plt.plot(frame['Cluster'], frame['SSE'], marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %% [markdown]
# ### We can see that the optimal number of clusters is 3. (The elbow of the graph)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(2)
kmeans.fit(data)
# Out:
# KMeans(n_clusters=2)

# %%
pd.DataFrame(kmeans.cluster_centers_, columns=features_2).T
# Out:
#                              0         1
# EN.ATM.METH.AG.KT.CE  1.131770  1.123761
# EN.ATM.METH.ZG        1.159601  1.127703
# time_code             3.285714  1.715131

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from IPython.display import clear_output

def plot_clusters(data, labels, centroids):
    pca = PCA(n_components=2)
    data_2d = pca.fit_transform(data)
    centroids_2d = pca.transform(centroids.T)
    clear_output(wait=True)
    plt.scatter(x=data_2d[:,0], y=data_2d[:,1], c=labels)
    plt.scatter(x=centroids_2d[:,0], y=centroids_2d[:,1])
    plt.show()

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
plot_clusters(data, labels, centroids.T)

# %%
labels = pd.DataFrame(labels, columns = ['labels'])
labels
# Out:
#       labels
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5071       0
# 5072       0
# 5073       0
# 5074       0
# 5075       0
#
# [5076 rows x 1 columns]

# %%
wme_df_origin = wme_df_origin.merge(labels, left_index=True, right_index=True, how='left').reset_index()

# %%
wme_df_origin
# Out:
#        index  Unnamed: 0 economy    time  EN.ATM.METH.AG.KT.CE  \
# 0          0           0     ABW  YR1960                   NaN
# 1          1           1     ABW  YR1961                   NaN
# 2          2           2     ABW  YR1962                   NaN
# 3          3           3     ABW  YR1963                   NaN
# 4          4           4     ABW  YR1964                   NaN
# ...      ...         ...     ...     ...                   ...
# 16487  16487       16487     ZWE  YR2017                6250.0
# 16488  16488       16488     ZWE  YR2018                6420.0
# 16489  16489       16489     ZWE  YR2019                6540.0
# 16490  16490       16490     ZWE  YR2020                   NaN
# 16491  16491       16491     ZWE  YR2021                   NaN
#
#        EN.ATM.METH.AG.ZS  EN.ATM.METH.EG.KT.CE  EN.ATM.METH.EG.ZS  \
# 0                    NaN                   NaN                NaN
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
# ...                  ...                   ...                ...
# 16487                NaN                2970.0                NaN
# 16488                NaN                3020.0                NaN
# 16489                NaN                3070.0                NaN
# 16490                NaN                   NaN                NaN
# 16491                NaN                   NaN                NaN
#
#        EN.ATM.METH.ZG  labels
# 0                 NaN     1.0
# 1                 NaN     1.0
# 2                 NaN     1.0
# 3                 NaN     1.0
# 4                 NaN     1.0
# ...               ...     ...
# 16487             NaN     NaN
# 16488             NaN     NaN
# 16489             NaN     NaN
# 16490             NaN     NaN
# 16491             NaN     NaN
#
# [16492 rows x 10 columns]

# %%
del wme_df['index']
del wme_df['Unnamed: 0']

# %%
del wme_df['level_0']

# %%
avg_df = wme_df_origin.groupby(['labels'], as_index=False).mean()
avg_df
# Out:
#    labels        index   Unnamed: 0  EN.ATM.METH.AG.KT.CE  EN.ATM.METH.AG.ZS  \
# 0     0.0  2543.428571  2543.428571          79949.963403          48.984132
# 1     1.0  2531.557396  2531.557396          86006.785714          48.896394
#
#    EN.ATM.METH.EG.KT.CE  EN.ATM.METH.EG.ZS  EN.ATM.METH.ZG
# 0          73741.991614          22.833303        9.481295
# 1          86380.707596          23.677030        8.308975

# %%
wb.series.info(q='methane')
# Out:
# id                    value
# --------------------  ---------------------------------------------------------------------------
# EN.ATM.METH.AG.KT.CE  Agricultural methane emissions (thousand metric tons of CO2 equivalent)
# EN.ATM.METH.AG.ZS     Agricultural methane emissions (% of total)
# EN.ATM.METH.EG.KT.CE  Methane emissions in energy sector (thousand metric tons of CO2 equivalent)
# EN.ATM.METH.EG.ZS     Energy related methane emissions (% of total)
# EN.ATM.METH.KT.CE     Methane emissions (kt of CO2 equivalent)
# EN.ATM.METH.ZG        Methane emissions (% change from 1990)
#                       6 elements

# %% [markdown]
# - EN.ATM.METH.AG.KT.CE and EN.ATM.METH.AG.ZS : Agricultural methane emissions are emissions from animals, animal waste, rice production, agricultural waste burning (nonenergy, on-site), and savanna burning.
#
#
# - EN.ATM.METH.EG.KT.CE and EN.ATM.METH.EG.ZS : Methane emissions from energy processes are emissions from the production, handling, transmission, and combustion of fossil fuels and biofuels.
#
# - EN.ATM.METH.KT.CE and  EN.ATM.METH.ZG: Methane emissions are those stemming from human activities such as agriculture and from industrial methane production.

# %% [markdown]
# ## Agriculture Sector

# %%
sns.barplot(x='labels',y='EN.ATM.METH.AG.KT.CE',data=avg_df)
# Out:
# <AxesSubplot: xlabel='labels', ylabel='EN.ATM.METH.AG.KT.CE'>

# %%
sns.barplot(x='labels',y='EN.ATM.METH.AG.ZS',data=avg_df)
# Out:
# <AxesSubplot: xlabel='labels', ylabel='EN.ATM.METH.AG.ZS'>

# %% [markdown]
# ## Energy sector

# %%
sns.barplot(x='labels',y='EN.ATM.METH.EG.KT.CE',data=avg_df)
# Out:
# <AxesSubplot: xlabel='labels', ylabel='EN.ATM.METH.EG.KT.CE'>

# %%
sns.barplot(x='labels',y='EN.ATM.METH.EG.ZS',data=avg_df)
# Out:
# <AxesSubplot: xlabel='labels', ylabel='EN.ATM.METH.EG.ZS'>

# %% [markdown]
# ## Both Energy and Agriculture sector

# %%
sns.barplot(x='labels',y='EN.ATM.METH.ZG',data=avg_df)
# Out:
# <AxesSubplot: xlabel='labels', ylabel='EN.ATM.METH.ZG'>

# %% [markdown]
# ### Building personas around each cluster

# %% [markdown]
# - Cluster 0 : Some country that have low average emission methane coming both from agriculture and energy
# - Cluster 1 : some country that have Low average emission from Energy sector mid average emission from agriculture sector
# - Cluster 2 : some country that have Low average emission from Agriculture sector mid average emission from Energy sector sector
# - Cluster 3 : some country that have high average emission from both Agriculture and Energy sector

# %%
wme_df_origin
# Out:
#        index  Unnamed: 0 economy    time  EN.ATM.METH.AG.KT.CE  \
# 0          0           0     ABW  YR1960                   NaN
# 1          1           1     ABW  YR1961                   NaN
# 2          2           2     ABW  YR1962                   NaN
# 3          3           3     ABW  YR1963                   NaN
# 4          4           4     ABW  YR1964                   NaN
# ...      ...         ...     ...     ...                   ...
# 16487  16487       16487     ZWE  YR2017                6250.0
# 16488  16488       16488     ZWE  YR2018                6420.0
# 16489  16489       16489     ZWE  YR2019                6540.0
# 16490  16490       16490     ZWE  YR2020                   NaN
# 16491  16491       16491     ZWE  YR2021                   NaN
#
#        EN.ATM.METH.AG.ZS  EN.ATM.METH.EG.KT.CE  EN.ATM.METH.EG.ZS  \
# 0                    NaN                   NaN                NaN
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
# ...                  ...                   ...                ...
# 16487                NaN                2970.0                NaN
# 16488                NaN                3020.0                NaN
# 16489                NaN                3070.0                NaN
# 16490                NaN                   NaN                NaN
# 16491                NaN                   NaN                NaN
#
#        EN.ATM.METH.ZG  labels
# 0                 NaN     1.0
# 1                 NaN     1.0
# 2                 NaN     1.0
# 3                 NaN     1.0
# 4                 NaN     1.0
# ...               ...     ...
# 16487             NaN     NaN
# 16488             NaN     NaN
# 16489             NaN     NaN
# 16490             NaN     NaN
# 16491             NaN     NaN
#
# [16492 rows x 10 columns]

# %%
wme_df_origin[(wme_df_origin['economy'] == 'FRA') & (wme_df_origin['EN.ATM.METH.EG.KT.CE'].isna())& (wme_df_origin['time']=='YR1970')]
# Out:
#       index  Unnamed: 0 economy    time  EN.ATM.METH.AG.KT.CE  \
# 4784   4784        4784     FRA  YR1970                   NaN
#
#       EN.ATM.METH.AG.ZS  EN.ATM.METH.EG.KT.CE  EN.ATM.METH.EG.ZS  \
# 4784          46.104492                   NaN          39.862416
#
#       EN.ATM.METH.ZG  labels
# 4784             NaN     0.0

# %%
avg_df = wme_df_origin.groupby(['time', 'labels'], as_index=False).mean()
avg_df[avg_df['EN.ATM.METH.EG.KT.CE'].isna()]
# Out:
#        time  labels        index   Unnamed: 0  EN.ATM.METH.AG.KT.CE  \
# 0    YR1960     0.0  2565.846154  2565.846154                   NaN
# 1    YR1960     1.0  2461.255814  2461.255814                   NaN
# 2    YR1961     0.0  2544.347826  2544.347826                   NaN
# 3    YR1961     1.0  2470.666667  2470.666667                   NaN
# 4    YR1962     0.0  2534.461538  2534.461538                   NaN
# ..      ...     ...          ...          ...                   ...
# 59   YR1989     1.0  2523.684211  2523.684211                   NaN
# 120  YR2020     0.0  2533.473684  2533.473684                   NaN
# 121  YR2020     1.0  2545.767442  2545.767442                   NaN
# 122  YR2021     0.0  2573.347826  2573.347826                   NaN
# 123  YR2021     1.0  2498.485714  2498.485714                   NaN
#
#      EN.ATM.METH.AG.ZS  EN.ATM.METH.EG.KT.CE  EN.ATM.METH.EG.ZS  \
# 0                  NaN                   NaN                NaN
# 1                  NaN                   NaN                NaN
# 2                  NaN                   NaN                NaN
# 3                  NaN                   NaN                NaN
# 4                  NaN                   NaN                NaN
# ..                 ...                   ...                ...
# 59           45.429615                   NaN           19.70218
# 120                NaN                   NaN                NaN
# 121                NaN                   NaN                NaN
# 122                NaN                   NaN                NaN
# 123                NaN                   NaN                NaN
#
#      EN.ATM.METH.ZG
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 59              NaN
# 120             NaN
# 121             NaN
# 122             NaN
# 123             NaN
#
# [64 rows x 9 columns]
